# %% [markdown]
# # Splitting Dataset Into Train and Test Datasets for Machine Learning Model

# %%
import seaborn as sb
from sklearn.model_selection import train_test_split

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sb.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### Splitting 20 Percent of Data for Testing and Remaining for Training

# %%
train,test=train_test_split(tips, test_size=0.2)

# %%
train
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 129       22.82  2.18    Male     No  Thur   Lunch     3
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 132       11.17  1.50  Female     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 134       18.26  3.25  Female     No  Thur   Lunch     2
#
# [195 rows x 7 columns]

# %%
test
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 112       38.07  4.00    Male     No   Sun  Dinner     3
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 104       20.92  4.08  Female     No   Sat  Dinner     2
# 122       14.26  2.50    Male     No  Thur   Lunch     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 89        21.16  3.00    Male     No  Thur   Lunch     2
# ...

# %% [markdown]
# #### Cross Checking The Percentages Of Data Split from Total Records Before

# %%
# 80 Percent for Training - 195 Records placed in Train Dataset
244*0.8
# Out:
# 195.20000000000002

# %%
train.shape
# Out:
# (195, 7)

# %%
# 20 Percent for Testing - 48-49 Records placed in Test Dataset
244*0.2
# Out:
# 48.800000000000004

# %%
test.shape
# Out:
# (49, 7)
